# %% [markdown]
# <a href="https://colab.research.google.com/github/XiaoLiang28/Xiao/blob/main/ps2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I want to explore the correlations among poverty, housing prices and unemployment rate in different areas in America in 2020.
#
# Poverty in the United States 2020 by State: https://data.ers.usda.gov/reports.aspx?ID=17826
#
# Median and Average Sales Price of Houses Sold by State 2020: https://en.wikipedia.org/wiki/List_of_U.S._states_by_median_home_price
#
# Annual unemployment rate in the United States in 2020, by state: https://www.bls.gov/lau/lastrk20.htm

# %%
import urllib 
import pandas as pd

# %%
urllib.request.urlretrieve("https://docs.google.com/uc?id=1jsZwHEIVF_SF3qARFnEeShwp2VaAU6ls&export=download","ex1.xlsx")
# Out:
# ('ex1.xlsx', <http.client.HTTPMessage at 0x7f4c1f4a42e0>)

# %%
"https://docs.google.com/uc?id=1jsZwHEIVF_SF3qARFnEeShwp2VaAU6ls&export=download","ex1.xlsx"
# Out:
# ('https://docs.google.com/uc?id=1jsZwHEIVF_SF3qARFnEeShwp2VaAU6ls&export=download',
#  'ex1.xlsx')

# %%
import os
os.getcwd() 
os.listdir()
# Out:
# ['.config', 'ex1.xlsx', 'sample_data']

# %%
'/content/ex1.csv'
# Out:
# '/content/ex1.csv'

# %%
dat='ex1.csv'

# %%
import pandas as pd

# %%
ex1=pd.read_excel('https://docs.google.com/uc?id=1jsZwHEIVF_SF3qARFnEeShwp2VaAU6ls&export=download',header=1)

# %%
ex1.dtypes
# Out:
# State rank                   object
# State or territory           object
# Median home price in US$    float64
# dtype: object

# %%
ex1.rename(columns={'State or territory': 'State Name','Median home price in US$': 'Price'},inplace=True)

# %%
ex1.head()
# Out:
#   State rank             State Name     Price
# 0        1.0                 Hawaii  636451.0
# 1          —   District of Columbia  626911.0
# 2        2.0             California  554886.0
# 3        3.0          Massachusetts  422856.0
# 4        4.0             Washington  409228.0

# %%
ex1
# Out:
#    State rank             State Name     Price
# 0         1.0                 Hawaii  636451.0
# 1           —   District of Columbia  626911.0
# 2         2.0             California  554886.0
# 3         3.0          Massachusetts  422856.0
# 4         4.0             Washington  409228.0
# 5         5.0               Colorado  397820.0
# 6         6.0                 Oregon  361970.0
# 7         7.0                   Utah  348376.0
# 8         8.0             New Jersey  335607.0
# 9         9.0               New York  321934.0
# 10       10.0               Maryland  308041.0
# 11       11.0                 Nevada  301753.0
# 12       12.0                 Alaska  300889.0
# 13       13.0           Rhode Island  300808.0
# 14       14.0          New Hampshire  290163.0
# 15       15.0                  Idaho  285982.0
# 16       16.0               Virginia  285229.0
# 17       17.0                Montana  277801.0
# 18       18.0                Arizona  268765.0
# ...

# %%
import urllib

# %%
# !wget -q -O a.xlsx https://docs.google.com/uc?id=161R6SzK9crGWUHelbjBODDlLHeycF0l4&export=download

# %%
urllib.request.urlretrieve("https://docs.google.com/uc?id=1AK6NmVWbA3orL6VdIdalXYLqs59PldVE&export=download","ex1.xlsx")
# Out:
# ('ex1.xlsx', <http.client.HTTPMessage at 0x7f4c1e4560d0>)

# %%
"https://docs.google.com/uc?id=1AK6NmVWbA3orL6VdIdalXYLqs59PldVE&export=download","ex1.xlsx"
# Out:
# ('https://docs.google.com/uc?id=1AK6NmVWbA3orL6VdIdalXYLqs59PldVE&export=download',
#  'ex1.xlsx')

# %%
import os
os.getcwd() 
os.listdir()
# Out:
# ['.config', 'ex1.xlsx', 'a.xlsx', 'sample_data']

# %%
'/content/ex1.csv'
# Out:
# '/content/ex1.csv'

# %%
dat='ex1.csv'

# %%
import pandas as pd

# %%
ex2=pd.read_excel("https://docs.google.com/uc?id=1AK6NmVWbA3orL6VdIdalXYLqs59PldVE&export=download")

# %%
ex2.rename(columns={'Unnamed: 0': 'State Name','Unnamed: 2': 'Rate'},inplace=True)

# %%
ex2
# Out:
#                       State Name Unnamed: 1     Rate Unnamed: 3  \
# 0   All people in poverty (2020)        NaN      NaN        NaN
# 1                            NaN        NaN      NaN        NaN
# 2                           Name   Unsorted  Percent   Unsorted
# 3                        Alabama        NaN     14.9        NaN
# 4                         Alaska        NaN      9.6        NaN
# 5                        Arizona        NaN     12.8        NaN
# 6                       Arkansas        NaN     15.2        NaN
# 7                     California        NaN     11.5        NaN
# 8                       Colorado        NaN        9        NaN
# 9                    Connecticut        NaN      9.7        NaN
# 10                      Delaware        NaN     10.9        NaN
# 11          District of Columbia        NaN       15        NaN
# 12                       Florida        NaN     12.4        NaN
# 13                       Georgia        NaN       14        NaN
# ...

# %%
ex2.head()
# Out:
#                      State Name Unnamed: 1     Rate Unnamed: 3  \
# 0  All people in poverty (2020)        NaN      NaN        NaN
# 1                           NaN        NaN      NaN        NaN
# 2                          Name   Unsorted  Percent   Unsorted
# 3                       Alabama        NaN     14.9        NaN
# 4                        Alaska        NaN      9.6        NaN
#
#                             Unnamed: 4 Unnamed: 5  \
# 0                                  NaN        NaN
# 1  90% confidence interval of estimate        NaN
# 2                          Lower Bound   Unsorted
# 3                                 14.5        NaN
# 4                                  9.1        NaN
#
#   Children ages 0-17 in poverty (2020) Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0                                  NaN        NaN        NaN        NaN
# 1                                  NaN        NaN        NaN        NaN
# ...

# %%
dat='ex1.csv'

# %%
import urllib

# %%
# !wget -q -O a.xlsx https://docs.google.com/uc?id=161R6SzK9crGWUHelbjBODDlLHeycF0l4&export=download

# %%
a=pd.read_excel("https://docs.google.com/uc?id=161R6SzK9crGWUHelbjBODDlLHeycF0l4&export=download")

# %%
a.rename(columns={'Unemployment Rates for States, 2020 Annual Averages': 'State Name','Unnamed: 1': 'Rate','Unnamed: 2': 'Rank'},inplace=True)

# %%
a
# Out:
#                                            State Name  Rate  Rank
# 0                                               State  2020  Rank
# 1                                                 NaN  rate   NaN
# 2                                       United States   8.1   NaN
# 3                                                 NaN   NaN   NaN
# 4                                            Nebraska   4.1     1
# 5                                        South Dakota   4.3     2
# 6                                                Utah   4.7     3
# 7                                               Maine     5     4
# 8                                                Iowa   5.1     5
# 9                                        North Dakota   5.1     5
# 10                                              Idaho   5.5     7
# 11                                            Vermont   5.6     8
# 12                                             Kansas   5.7     9
# ...

# %%
mergedOuter = pd.merge(ex1, ex2, how='outer', on=['State Name'],indicator=True)
mergedOuter
# Out:
#     State rank             State Name     Price Unnamed: 1  Rate Unnamed: 3  \
# 0          1.0                 Hawaii  636451.0        NaN   NaN        NaN
# 1            —   District of Columbia  626911.0        NaN   NaN        NaN
# 2          2.0             California  554886.0        NaN   NaN        NaN
# 3          3.0          Massachusetts  422856.0        NaN   NaN        NaN
# 4          4.0             Washington  409228.0        NaN   NaN        NaN
# ..         ...                    ...       ...        ...   ...        ...
# 101        NaN               Virginia       NaN        NaN   9.2        NaN
# 102        NaN             Washington       NaN        NaN   9.5        NaN
# 103        NaN          West Virginia       NaN        NaN  15.8        NaN
# 104        NaN              Wisconsin       NaN        NaN    10        NaN
# 105        NaN                Wyoming       NaN        NaN   9.2        NaN
#
# ...

# %%
ex1.dtypes
# Out:
# State rank     object
# State Name     object
# Price         float64
# dtype: object

# %%
mergedOuter['_merge'].value_counts()
mergedOuter['State Name'][mergedOuter['_merge']=='left_only']
mergedOuter['State Name'][mergedOuter['_merge']=='right_only']
# Out:
# 51     All people in poverty (2020)
# 52                              NaN
# 53                             Name
# 54                          Alabama
# 55                           Alaska
# 56                          Arizona
# 57                         Arkansas
# 58                       California
# 59                         Colorado
# 60                      Connecticut
# 61                         Delaware
# 62             District of Columbia
# 63                          Florida
# 64                          Georgia
# 65                           Hawaii
# 66                            Idaho
# 67                         Illinois
# 68                          Indiana
# 69                             Iowa
# 70                           Kansas
# 71                         Kentucky
# 72                        Louisiana
# 73                            Maine
# 74                         Maryland
# 75                    Massachusetts
# 76                         Michigan
# ...

# %%
mergedInner = pd.merge(ex1, ex2, how='inner', on=['State Name'])
mergedInner
# Out:
# Empty DataFrame
# Columns: [State rank, State Name, Price, Unnamed: 1, Rate, Unnamed: 3, Unnamed: 4, Unnamed: 5, Children ages 0-17 in poverty (2020), Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13]
# Index: []

# %%
mergedLeft = pd.merge(ex1, ex2, how='left', on=['State Name'])
mergedLeft
# Out:
#    State rank             State Name     Price Unnamed: 1 Rate Unnamed: 3  \
# 0         1.0                 Hawaii  636451.0        NaN  NaN        NaN
# 1           —   District of Columbia  626911.0        NaN  NaN        NaN
# 2         2.0             California  554886.0        NaN  NaN        NaN
# 3         3.0          Massachusetts  422856.0        NaN  NaN        NaN
# 4         4.0             Washington  409228.0        NaN  NaN        NaN
# 5         5.0               Colorado  397820.0        NaN  NaN        NaN
# 6         6.0                 Oregon  361970.0        NaN  NaN        NaN
# 7         7.0                   Utah  348376.0        NaN  NaN        NaN
# 8         8.0             New Jersey  335607.0        NaN  NaN        NaN
# 9         9.0               New York  321934.0        NaN  NaN        NaN
# 10       10.0               Maryland  308041.0        NaN  NaN        NaN
# 11       11.0                 Nevada  301753.0        NaN  NaN        NaN
# ...

# %%
mergedRight = pd.merge(ex1, ex2, how='right', on=['State Name'])
mergedRight
# Out:
#    State rank                    State Name     Price Unnamed: 1     Rate  \
# 0         NaN  All people in poverty (2020)       NaN        NaN      NaN
# 1         NaN                           NaN       NaN        NaN      NaN
# 2         NaN                          Name       NaN   Unsorted  Percent
# 3        46.0                       Alabama  138975.0        NaN     14.9
# 4        12.0                        Alaska  300889.0        NaN      9.6
# 5        18.0                       Arizona  268765.0        NaN     12.8
# 6        48.0                      Arkansas  128101.0        NaN     15.2
# 7         2.0                    California  554886.0        NaN     11.5
# 8         5.0                      Colorado  397820.0        NaN        9
# 9        20.0                   Connecticut  255555.0        NaN      9.7
# 10       22.0                      Delaware  254108.0        NaN     10.9
# 11          —          District of Columbia  626911.0        NaN       15
# ...

# %%
ex1['State Name']=ex1['State Name'].str.strip()

# %%
ex2['State Name']=ex2['State Name'].str.strip()

# %%
ex2
# Out:
#                       State Name Unnamed: 1     Rate Unnamed: 3  \
# 0   All people in poverty (2020)        NaN      NaN        NaN
# 1                            NaN        NaN      NaN        NaN
# 2                           Name   Unsorted  Percent   Unsorted
# 3                        Alabama        NaN     14.9        NaN
# 4                         Alaska        NaN      9.6        NaN
# 5                        Arizona        NaN     12.8        NaN
# 6                       Arkansas        NaN     15.2        NaN
# 7                     California        NaN     11.5        NaN
# 8                       Colorado        NaN        9        NaN
# 9                    Connecticut        NaN      9.7        NaN
# 10                      Delaware        NaN     10.9        NaN
# 11          District of Columbia        NaN       15        NaN
# 12                       Florida        NaN     12.4        NaN
# 13                       Georgia        NaN       14        NaN
# ...

# %%
ex2['State Name']
# Out:
# 0     All people in poverty (2020)
# 1                              NaN
# 2                             Name
# 3                          Alabama
# 4                           Alaska
# 5                          Arizona
# 6                         Arkansas
# 7                       California
# 8                         Colorado
# 9                      Connecticut
# 10                        Delaware
# 11            District of Columbia
# 12                         Florida
# 13                         Georgia
# 14                          Hawaii
# 15                           Idaho
# 16                        Illinois
# 17                         Indiana
# 18                            Iowa
# 19                          Kansas
# 20                        Kentucky
# 21                       Louisiana
# 22                           Maine
# 23                        Maryland
# 24                   Massachusetts
# 25                        Michigan
# 26                       Minnesota
# ...

# %%
ex1_2 = pd.merge(ex1, ex2, how='right', on=['State Name'], indicator=True)
mergedRight
# Out:
#    State rank                    State Name     Price Unnamed: 1     Rate  \
# 0         NaN  All people in poverty (2020)       NaN        NaN      NaN
# 1         NaN                           NaN       NaN        NaN      NaN
# 2         NaN                          Name       NaN   Unsorted  Percent
# 3        46.0                       Alabama  138975.0        NaN     14.9
# 4        12.0                        Alaska  300889.0        NaN      9.6
# 5        18.0                       Arizona  268765.0        NaN     12.8
# 6        48.0                      Arkansas  128101.0        NaN     15.2
# 7         2.0                    California  554886.0        NaN     11.5
# 8         5.0                      Colorado  397820.0        NaN        9
# 9        20.0                   Connecticut  255555.0        NaN      9.7
# 10       22.0                      Delaware  254108.0        NaN     10.9
# 11          —          District of Columbia  626911.0        NaN       15
# ...

# %%
mergedOuter = pd.merge(ex1_2, a, how='outer', on=['State Name'],indicator='exists')
mergedOuter
# Out:
#    State rank                                         State Name     Price  \
# 0         NaN                       All people in poverty (2020)       NaN
# 1         NaN                                                NaN       NaN
# 2         NaN                                                NaN       NaN
# 3         NaN                                               Name       NaN
# 4        46.0                                            Alabama  138975.0
# 5        12.0                                             Alaska  300889.0
# 6        18.0                                            Arizona  268765.0
# 7        48.0                                           Arkansas  128101.0
# 8         2.0                                         California  554886.0
# 9         5.0                                           Colorado  397820.0
# 10       20.0                                        Connecticut  255555.0
# ...

# %%
mergedOuter['_merge'].value_counts()
# Out:
# both          51
# right_only     5
# left_only      0
# Name: _merge, dtype: int64

# %%
mergedOuter['State Name'][mergedOuter['_merge']=='left_only']
# Out:
# Series([], Name: State Name, dtype: object)

# %%
mergedOuter['State Name'][mergedOuter['_merge']=='right_only']
# Out:
# 0     All people in poverty (2020)
# 1                              NaN
# 2                              NaN
# 3                             Name
# 31                        National
# Name: State Name, dtype: object

# %%
mergedInner = pd.merge(ex1_2, a, how='inner', on=['State Name'])
mergedInner
# Out:
#    State rank            State Name     Price Unnamed: 1 Rate_x Unnamed: 3  \
# 0         NaN                   NaN       NaN        NaN    NaN        NaN
# 1         NaN                   NaN       NaN        NaN    NaN        NaN
# 2        46.0               Alabama  138975.0        NaN   14.9        NaN
# 3        12.0                Alaska  300889.0        NaN    9.6        NaN
# 4        18.0               Arizona  268765.0        NaN   12.8        NaN
# 5        48.0              Arkansas  128101.0        NaN   15.2        NaN
# 6         2.0            California  554886.0        NaN   11.5        NaN
# 7         5.0              Colorado  397820.0        NaN      9        NaN
# 8        20.0           Connecticut  255555.0        NaN    9.7        NaN
# 9        22.0              Delaware  254108.0        NaN   10.9        NaN
# 10          —  District of Columbia  626911.0        NaN     15        NaN
# ...

# %%
mergedLeft = pd.merge(ex1_2, a, how='left', on=['State Name'])
mergedLeft
# Out:
#    State rank                    State Name     Price Unnamed: 1   Rate_x  \
# 0         NaN  All people in poverty (2020)       NaN        NaN      NaN
# 1         NaN                           NaN       NaN        NaN      NaN
# 2         NaN                           NaN       NaN        NaN      NaN
# 3         NaN                          Name       NaN   Unsorted  Percent
# 4        46.0                       Alabama  138975.0        NaN     14.9
# 5        12.0                        Alaska  300889.0        NaN      9.6
# 6        18.0                       Arizona  268765.0        NaN     12.8
# 7        48.0                      Arkansas  128101.0        NaN     15.2
# 8         2.0                    California  554886.0        NaN     11.5
# 9         5.0                      Colorado  397820.0        NaN        9
# 10       20.0                   Connecticut  255555.0        NaN      9.7
# 11       22.0                      Delaware  254108.0        NaN     10.9
# ...

# %%
mergedRight = pd.merge(ex1_2, a, how='right', on=['State Name'])
mergedRight
# Out:
#    State rank                                         State Name     Price  \
# 0         NaN                                              State       NaN
# 1         NaN                                                NaN       NaN
# 2         NaN                                      United States       NaN
# 3         NaN                                                NaN       NaN
# 4        37.0                                           Nebraska  175884.0
# 5        28.0                                       South Dakota  205567.0
# 6         7.0                                               Utah  348376.0
# 7        25.0                                              Maine  242316.0
# 8        42.0                                               Iowa  152885.0
# 9        26.0                                       North Dakota  235012.0
# 10       15.0                                              Idaho  285982.0
# ...
