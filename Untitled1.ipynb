# %% [markdown]
# <a href="https://colab.research.google.com/github/XiaoLiang28/Xiao/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Childhood poverty has deep impacts to individual's life and development in the future. Therefore, it is important to analyze the geographical condition of childhood poverty for future policy advices. The data I choose in the first database is about children under age 5 living in poverty by county in New Jersey. The variables are counties in New Jersey, the estimated percent of children under 5 who live in poverty divided by county in NJ, the numerator (number of children under 5 who live in poverty in a geographic area), and the denominator (the total number of children under 5 who live in a geographic area). The last two variables will not be used in ps1.
#
# My research question is "How does adults education level influence the percent of children under 5 living in poverty in New Jersey from 2016-2020?" My hypothesis is "The counties with higher adults college completion rates have lower rates of children under 5 living in poverty in NJ from 2016-2020. I will find data about the adults' education level in New Jersey in the next ps and try to prove my hypothesis.

# %%
import urllib

# %%
urllib.request.urlretrieve("https://github.com/XiaoLiang28/Xiao/blob/main/Children%20under%205%20Live%20in%20Poverty%20in%20NJ.xlsx?raw=true", "ex1.xlsx")
# Out:
# ('ex1.xlsx', <http.client.HTTPMessage at 0x7f472e1630a0>)

# %%
"https://github.com/XiaoLiang28/Xiao/blob/main/Children%20under%205%20Live%20in%20Poverty%20in%20NJ.xlsx","ex1.xlsx"
# Out:
# ('https://github.com/XiaoLiang28/Xiao/blob/main/Children%20under%205%20Live%20in%20Poverty%20in%20NJ.xlsx',
#  'ex1.xlsx')

# %%
import os
os.getcwd() 
os.listdir()
# Out:
# ['.config', 'ex1.xlsx', 'sample_data']

# %%
'/content/ex1.csv'
# Out:
# '/content/ex1.csv'

# %%
dat='ex1.csv'

# %%
import pandas as pd

# %%
dat=pd.read_excel("ex1.xlsx")

# %%
dat #print it out
# Out:
#         County  Estimated Percent  Numerator  Denominator
# 0     Atlantic              0.236       3335        14124
# 1       Bergen              0.064       3098        48651
# 2   Burlington              0.109       2418        22124
# 3       Camden              0.184       5571        30306
# 4     Cape May              0.135        565         4175
# 5   Cumberland              0.192       1820         9485
# 6        Essex              0.221      11495        52081
# 7   Gloucester              0.085       1287        15072
# 8       Hudson              0.167       7697        46174
# 9    Hunterdon              0.038        190         5049
# 10      Mercer              0.185       3802        20595
# 11   Middlesex              0.113       5307        47136
# 12    Monmouth              0.077       2333        30447
# 13      Morris              0.046       1130        24483
# 14       Ocean              0.191       8055        42281
# ...

# %%
dat["Numerator"][0:3]
# Out:
# 0    3335
# 1    3098
# 2    2418
# Name: Numerator, dtype: int64

# %%
dat[["Numerator","Denominator"]][0:3]
# Out:
#    Numerator  Denominator
# 0       3335        14124
# 1       3098        48651
# 2       2418        22124

# %%
dat.sample(frac=0.5, replace=False, random_state=1)
# Out:
#         County  Estimated Percent  Numerator  Denominator
# 19       Union              0.124       4321        34760
# 16       Salem              0.253        842         3325
# 3       Camden              0.184       5571        30306
# 13      Morris              0.046       1130        24483
# 18      Sussex              0.061        383         6259
# 15     Passaic              0.254       8508        33432
# 10      Mercer              0.185       3802        20595
# 4     Cape May              0.135        565         4175
# 2   Burlington              0.109       2418        22124
# 17    Somerset              0.060       1018        16891
# 6        Essex              0.221      11495        52081

# %%
#dat["Estimated Percent"]

# %%
dat["Estimated Percent"].mean()
# Out:
# 0.13772727272727273

# %%
dat["Numerator"].value_counts()
# Out:
# 3335     1
# 3098     1
# 447      1
# 4321     1
# 383      1
# 1018     1
# 842      1
# 8508     1
# 8055     1
# 1130     1
# 2333     1
# 5307     1
# 3802     1
# 190      1
# 7697     1
# 1287     1
# 11495    1
# 1820     1
# 565      1
# 5571     1
# 2418     1
# 73622    1
# Name: Numerator, dtype: int64

# %%
dat["Denominator"].hist()

# %%
pd.crosstab(dat["Numerator"], dat["Denominator"])
# Out:
# Denominator  3325    4175    4790    5049    6259    9485    14124   15072   \
# Numerator
# 190               0       0       0       1       0       0       0       0
# 383               0       0       0       0       1       0       0       0
# 447               0       0       1       0       0       0       0       0
# 565               0       1       0       0       0       0       0       0
# 842               1       0       0       0       0       0       0       0
# 1018              0       0       0       0       0       0       0       0
# 1130              0       0       0       0       0       0       0       0
# 1287              0       0       0       0       0       0       0       1
# 1820              0       0       0       0       0       1       0       0
# 2333              0       0       0       0       0       0       0       0
# 2418              0       0       0       0       0       0       0       0
# ...

# %%
dat.plot(kind='scatter', y='Denominator', x='Numerator')

# %%
dat[['Numerator','Denominator']].corr().round(2)
# Out:
#              Numerator  Denominator
# Numerator         1.00         0.99
# Denominator       0.99         1.00
