# %% [markdown]
# <a href="https://colab.research.google.com/github/XiaoLiang28/Xiao/blob/main/draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import data_table
data_table.enable_dataframe_formatter() #this enables spreadsheet view upon calling dataframe (without() )

from google.colab.data_table import DataTable
DataTable.max_columns = 200

# %%
df=pd.read_excel('https://github.com/XiaoLiang28/Xiao/raw/main/Gender%20Development.xlsx')

# %%
df.head(10)
# Out:
#        Back Table 4. Gender Development Index                Unnamed: 2  \
# 0       NaN                               NaN                       NaN
# 1       NaN                               NaN                       NaN
# 2       NaN                               NaN  Gender Development Index
# 3       NaN                               NaN                       NaN
# 4  HDI rank                           Country                     Value
# 5       NaN                               NaN                      2021
# 6       NaN       VERY HIGH HUMAN DEVELOPMENT                       NaN
# 7         1                       Switzerland                     0.967
# 8         2                            Norway                     0.983
# 9         3                           Iceland                     0.976
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5               Unnamed: 6  Unnamed: 7  \
# 0         NaN        NaN        NaN                      NaN         NaN
# ...

# %%
df.rename(columns={'Table 4. Gender Development Index': 'country'},inplace=True)
df.rename(columns={'Unnamed: 2': 'gender dev ind'},inplace=True)

# %%
df1=df[7:201] #subset going from 7th row till the end

# %%
df2=df1[['country','gender dev ind']]

# %%
df2
# Out:
#                       country gender dev ind
# 7                 Switzerland          0.967
# 8                      Norway          0.983
# 9                     Iceland          0.976
# 10     Hong Kong, China (SAR)          0.976
# 11                  Australia          0.968
# ..                        ...            ...
# 196                   Burundi          0.935
# 197  Central African Republic           0.81
# 198                     Niger          0.835
# 199                      Chad           0.77
# 200               South Sudan          0.843
#
# [194 rows x 2 columns]

# %%
df2.dtypes
# Out:
# country           object
# gender dev ind    object
# dtype: object

# %%
df3 = df2.replace('..', np.nan)

# %%
df3['gender dev ind'] = df3['gender dev ind'].astype(float)

# %%
df3.dtypes
# Out:
# country            object
# gender dev ind    float64
# dtype: object

# %%
df3
# Out:
#                       country  gender dev ind
# 7                 Switzerland           0.967
# 8                      Norway           0.983
# 9                     Iceland           0.976
# 10     Hong Kong, China (SAR)           0.976
# 11                  Australia           0.968
# ..                        ...             ...
# 196                   Burundi           0.935
# 197  Central African Republic           0.810
# 198                     Niger           0.835
# 199                      Chad           0.770
# 200               South Sudan           0.843
#
# [194 rows x 2 columns]

# %%
#abortionmerge = abortionCen[['State', 'Abortion rate among women aged 15-44 (2020)']]

# drop any rows with missing data
#abortionmerge = abortionmerge.dropna()

# sort the data by descending order of abortion rate
#abortionmerge = abortionmerge.sort_values(by='Abortion rate among women aged 15-44 (2020)', ascending=False)

# create a horizontal bar chart
fig, ax = plt.subplots(figsize=(8, 40))
ax.barh(df3['country'], df3['gender dev ind'])
ax.set_xlabel('Abortion rate among women aged 15-44')
ax.set_ylabel('State')
ax.set_title('Abortion Rates by State - 2020')
plt.show()
# Out:
# <BarContainer object of 194 artists>
# Text(0.5, 0, 'Abortion rate among women aged 15-44')
# Text(0, 0.5, 'State')
# Text(0.5, 1.0, 'Abortion Rates by State - 2020')

# %%
pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 99.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 119.9 MB/s eta 0:00:00
# ...

# %%
import geopandas as gpd

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
world.dtypes
# Out:
# pop_est        float64
# continent       object
# name            object
# iso_a3          object
# gdp_md_est       int64
# geometry      geometry
# dtype: object

# %%
world.head(10)
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
# 5   18513930.0           Asia                Kazakhstan    KAZ      181665
# 6   33580650.0           Asia                Uzbekistan    UZB       57921
# 7    8776109.0        Oceania          Papua New Guinea    PNG       24829
# 8  270625568.0           Asia                 Indonesia    IDN     1119190
# 9   44938712.0  South America                 Argentina    ARG      445445
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# ...
